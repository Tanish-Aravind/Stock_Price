# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanish-Aravind/Stock_Price/blob/main/StockPricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_percentage_error

# %%
df= pd.read_csv('stock_data.csv')
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Stock_1       0
# Stock_2       0
# Stock_3       0
# Stock_4       0
# Stock_5       0
# dtype: int64

# %%
df.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['IsWeekend'] = df['Date'].dt.dayofweek.isin([5, 6]).astype(int)

# %%
df
# Out:
#           Date     Stock_1     Stock_2  ...  Day  DayOfWeek  IsWeekend
# 0   2020-01-01  101.764052  100.160928  ...    1          2          0
# 1   2020-01-02  102.171269   99.969968  ...    2          3          0
# 2   2020-01-03  103.171258   99.575237  ...    3          4          0
# 3   2020-01-04  105.483215   99.308641  ...    4          5          1
# 4   2020-01-05  107.453175   98.188428  ...    5          6          1
# ..         ...         ...         ...  ...  ...        ...        ...
# 360 2020-12-26   92.684784   63.408103  ...   26          5          1
# 361 2020-12-27   92.688279   62.816639  ...   27          6          1
# 362 2020-12-28   93.551993   63.597651  ...   28          0          0
# 363 2020-12-29   93.870037   64.114492  ...   29          1          0
# 364 2020-12-30   93.855317   64.491011  ...   30          2          0
#
# [365 rows x 11 columns]

# %%
df = df.drop(columns=['Date'])

# %%
df
# Out:
#         Stock_1     Stock_2    Stock_3  ...  Day  DayOfWeek  IsWeekend
# 0    101.764052  100.160928  99.494642  ...    1          2          0
# 1    102.171269   99.969968  98.682973  ...    2          3          0
# 2    103.171258   99.575237  98.182139  ...    3          4          0
# 3    105.483215   99.308641  97.149381  ...    4          5          1
# 4    107.453175   98.188428  99.575396  ...    5          6          1
# ..          ...         ...        ...  ...  ...        ...        ...
# 360   92.684784   63.408103  98.288992  ...   26          5          1
# 361   92.688279   62.816639  98.061845  ...   27          6          1
# 362   93.551993   63.597651  96.454800  ...   28          0          0
# 363   93.870037   64.114492  95.747485  ...   29          1          0
# 364   93.855317   64.491011  97.805648  ...   30          2          0
#
# [365 rows x 10 columns]

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

df = pd.read_csv('stock_data.csv')
df.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['DayOfWeek'] = df['Date'].dt.dayofweek
df['IsWeekend'] = df['Date'].dt.dayofweek.isin([5, 6]).astype(int)

stock_cols = ['Stock_1', 'Stock_2', 'Stock_3', 'Stock_4', 'Stock_5']

for stock in stock_cols:
    temp_df = df[['Month', 'Day', 'DayOfWeek', 'IsWeekend', stock]].copy()
    temp_df['Price_Yesterday'] = temp_df[stock].shift(1)
    temp_df['Price_2DaysAgo'] = temp_df[stock].shift(2)
    temp_df = temp_df.dropna()

    X = temp_df.drop(columns=[stock])
    y = temp_df[stock]

    split_idx = int(len(temp_df) * 0.8)
    X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
    y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

    model = RandomForestRegressor(n_estimators=200, max_depth=5, min_samples_leaf=1, random_state=42)
    model.fit(X_train, y_train)

    train_r2 = r2_score(y_train, model.predict(X_train))
    test_r2 = r2_score(y_test, model.predict(X_test))

    print(f"{stock} -> Train R2: {train_r2:.4f}, Test R2: {test_r2:.4f}")
# Out:
# Stock_1 -> Train R2: 0.9867, Test R2: 0.7753
# Stock_2 -> Train R2: 0.9950, Test R2: -5.5613
# Stock_3 -> Train R2: 0.9873, Test R2: -0.0449
# Stock_4 -> Train R2: 0.9859, Test R2: 0.8969
# Stock_5 -> Train R2: 0.9595, Test R2: 0.8027
